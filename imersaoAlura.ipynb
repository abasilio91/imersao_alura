# %% [markdown]
# <a href="https://colab.research.google.com/github/abasilio91/imersao_alura/blob/main/imersaoAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### AULA 01

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
url = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url, compression='zip')
dados.columns = dados.columns.str.replace('-','')
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# O número de drogas utilizado no grupo de controle foi apenas uma, possivelmente um placebo. Em números absolutos, a quantidade de experimentos feitos com drogas é muito mais elevado. Isso garante relevância estatística ao procedimento e robustez numérica (desvio-padrão baixo). No entanto, em números relativos, nota-se uma quantidade muito maior de experimentos feitos com a droga de controle em relação às drogas clínicas, mostrando que, na verdade, o grupo de controle é elevado, aumentando a credibilidade da segurança dos testes.

# %%
dados_filtrados_controle = dados.groupby('tratamento').get_group('com_controle')
drogas_con = dados_filtrados_controle['droga'].nunique()
doses_con = dados_filtrados_controle['dose'].nunique()
tempo_con = dados_filtrados_controle['tempo'].nunique()
num_exp_con = dados_filtrados_controle['tratamento'].count()
combinacao_exps_con = drogas_con * doses_con * tempo_con
razao_con = num_exp_con / combinacao_exps_con

dados_filtrados_droga = dados.groupby('tratamento').get_group('com_droga')
drogas_drg = dados_filtrados_droga['droga'].nunique()
doses_drg = dados_filtrados_droga['dose'].nunique()
tempo_drg = dados_filtrados_droga['tempo'].nunique()
num_exp_drg = dados_filtrados_droga['tratamento'].count()
combinacao_exps_drg = drogas_drg * doses_drg * tempo_drg
razao_drg = num_exp_drg / combinacao_exps_drg

print(f'controle: drogas: {drogas_con}; doses: {doses_con}; tempo: {tempo_con}; total de experimentos: {num_exp_con}; razao experimento/drogas = {razao_con} \n')
print(f'clinico: drogas: {drogas_drg}; doses: {doses_drg}; tempo: {tempo_drg}; total de experimentos: {num_exp_drg}; razao experimento/drogas = {razao_drg} \n')
# Out:
# controle: drogas: 1; doses: 2; tempo: 3; total de experimentos: 1866; razao experimento/drogas = 311.0
#
# clinico: drogas: 3288; doses: 2; tempo: 3; total de experimentos: 21948; razao experimento/drogas = 1.112530413625304

# %% [markdown]
# ## Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ## Desafio 04: Quantas tipos de drogas foram investigados.

# %%
dados['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# ## Desafio 05: Procurar na documentação o método query(pandas).

# %%
dados_filtrados = dados.query('g0>1')
dados_filtrados.head()
# Out:
#               id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0   id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 6   id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 16  id_002fb9c19  com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 39  id_0079d45d3  com_droga     24   D1  ... -2.7020 -2.2530 -4.8360 -0.6461
# 48  id_008b48693  com_droga     24   D1  ... -0.2725 -0.1511 -0.4635 -0.1365
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 06: Renomear as colunas tirando o hífen.

# %%
# dados.columns = dados.columns.str.replace('-','') # Já executado no começo do programa

# %% [markdown]
# ## Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
dados['tempo'].value_counts().plot.bar()
plt.xlabel('tempo')
plt.ylabel('contagens')
plt.title('Contagem de experimentos por tempo')
# Out:
# Text(0.5, 1.0, 'Contagem de experimentos por tempo')

# %% [markdown]
# ## Desafio 08: Resumo do que você aprendeu com os dados
#
# As principais novidades técnicas dessa aula foi:
#
# 1.   Uma nova forma de ler arquivos .csv (arquivos zipados) utilizando a biblioteca Pandas
# 2.   Novos métodos da biblioteca (.nunique; .str.replace, .query), que eu não conhecia mas são bastante interessantes e úteis
# 3.   O desafio 01 foi, de fato, bem desafiador e curioso na questão de avaliar a entender a discrepância dos dados. Por não ser da área da saúde, foi preciso um razoável nível de estudo do tema até ter uma ideia de um tipo de análise que poderia ser feito nesse sentido.

# %% [markdown]
# ### AULA 02

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10,8))
ax = sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].hist(bins=100)

# %%
dados['g19'].hist(bins=100)

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0',data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='g0',y='tratamento',data=dados)

# %% [markdown]
# ###Desafio 01: Ordenar o gráfico countplot

# %%
# gráfico original

sns.set()
plt.figure(figsize=(10,8))
ax = sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
# gráfico ordenado maior-menor

sns.set()
plt.figure(figsize=(10,8))
ax = sns.countplot(x='composto',
                   data=dados.query('composto in @cod_compostos'),
                   order=dados.query('composto in @cod_compostos')['composto'].value_counts().index)
ax.set_title('Top 5 compostos')
plt.show()

# %%
# gráfico ordenado menor-maior

sns.set()
plt.figure(figsize=(10,8))
ax = sns.countplot(x='composto',
                   data=dados.query('composto in @cod_compostos'),
                   order=dados.query('composto in @cod_compostos')['composto'].value_counts(ascending=True).index)
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# ### Desafio 02: Melhorar a visualização alterando tamanho da fonte...

# %%
sns.set(font='Times New Roman', font_scale=1.5)

plt.figure(figsize=(10,8))

ax = sns.countplot(x='composto',
                   data=dados.query('composto in @cod_compostos'),
                   order=dados.query('composto in @cod_compostos')['composto'].value_counts().index)
ax.set_title('Top 5 compostos')
# Out:
# Text(0.5, 1.0, 'Top 5 compostos')
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Desafio 03: Plotar os histogramas com seaborn

# %%
sns.histplot(dados['g0'])

# %%
sns.histplot(dados['g19'])

# %% [markdown]
# ### Desafio 04: Estudar sobre as estatíticas retornadas no .describe()

# %%
dados['g0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g0, dtype: float64

# %% [markdown]
# count = contagem de quantos elementos existem na série
#
# *   count = contagem de quantos elementos existem na série.
# *   mean = média aritmética dos valores da série.
# *   std = desvio-padrão amostral dos valores da série.
# *   min = menor valor da série.
# *   25% = valor cuja posição separa os dados na proporção (25%,75%), ou seja, 25% dos valores da série são menores que este valor e 75% dos valores são maiores que este. Em estatística, este valor é chamado de 1º quantil.
# *   50% = valor cuja posição separa os dados na proporção (50%,50%). Chamado de 2º quantil ou mediana.
# *   75% = valor cuja posição separa os dados na proporção (75%,25%). Chamado de 3º quantil.
# *   max = maior valor da série.

# %% [markdown]
# ### Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %%
plt.figure()
sns.boxplot(x='g0',y='tratamento',data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='g0',y='tratamento',data=dados)

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='g0',y='tratamento',data=dados)

# %% [markdown]
# Quando se fala em visualização de dados, várias questões devem ser levadas em consideração além dos dados propriamente dito. Tamanho de fonte e de imagem, por exemplo, são fatores que não devem ser ignorados ao se prepara uma imagem representativa.
#
# Uma imagem com resolução baixa será de difícil leitura; se a resolução for muito alta, poderá gerar problemas ao carregá-la. Uma imagem pequena tem menos espaços para passar informações, prejudicando a quantidade de dados que podem ser apresentados. Uma imagem exageradamente terá um maior espaçamento entre as informações, podendo levar à falsa ideia de poucos dados, ou falta de dados. O tamanho da fonte na imagem, idealmente, deve ser o mais próximo possível do tamanho da fonte no texto que a acompanhar.

# %% [markdown]
# ### Desafio 06: Fazer outras análises com o boxplot e até com o histograma.

# %%
fig, axs = plt.subplots(1,2,figsize=(30,8))

ax = sns.boxplot(y='g0', x='dose', ax=axs[0], data=dados, hue='tempo')
ax.legend(bbox_to_anchor=(1.12,1))

ax = sns.boxplot(y='g0', x='tempo', ax=axs[1], data=dados, hue='dose')
ax.legend(bbox_to_anchor=(1.12,1))

plt.show()

# %% [markdown]
# A primeira apresenta a média das respostas de g0 ao estimulo das drogas em relação à dosagem e ao tempo. A mediana permaneceu próxima a zero em todos os casos, enquanto os primeiros e terceiros quantis ficaram próximoas a -2 e 2, respectivamente, com uma maior variação acontecendo no período de 48h de observação. Observou-se uma grande quantidade de outliers em todos os casos.

# %% [markdown]
# A segunda mostra a distribuição das contagens médias em relação tempo separadas por doses. Nesta imagem, nota-se que houve uma diferença entre contagens no tempo = 48h, enquanto que nos demais tempo a distribuição de contagens ficaram próximas. Combinado com a imagem anterior, fica claro que o tmepo de 48h representa um ponto importante a ser investigado, a fim de entender o que acontece com o gene após esse tempo que justifique a dispersão mais próxima de zero para este tempo.

# %%
fig, axs = plt.subplots(1,2,figsize=(30,8))

ax = sns.boxplot(y='g0', x='tempo', ax=axs[0], data=dados, hue='dose')
ax.legend(bbox_to_anchor=(1.12,1))

ax = sns.boxplot(y='g1', x='tempo', ax=axs[1], data=dados, hue='dose')
ax.legend(bbox_to_anchor=(1.12,1))

plt.show()

# %% [markdown]
# Este figura faz uma comparação das respostas dos genes g0 e g1 ao longo do tempo em relação às doses aplicadas. Observa-se que, para o tempo=48h, houve um achatamento considerável do box para o gene g0, enquanto que este mesmo fenômeno também foi observado, porém com menor intensidade. Nota-se, também, um leve deslocamento nos quantis para o caso do gene g1 em relação à segunda dose, enquanto que, para g0, tal fato não ocorreu.

# %% [markdown]
# ### Desafio 07: Resumo do que você aprendeu com os dados
#
# Esta aula foi focada mais na técnica de representação de dados. Aplicando estes conhecimentos foi possível obter algumas informações básicas a respeito das respostas dos genes em relação ao estímulo do composto.

# %% [markdown]
# ### AULA 03

# %%
# Tabela de frequência do pandas

pd.crosstab(dados['dose'], dados['tempo']) # dados com controle e com droga misturados
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento']) # dados com controle e com drogas explicitos, porém absolutos
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize=True) # dados com controle e com drogas explicitos e normalizados (total)
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index') # dados com controle e com drogas explicitos e normalizados por linhas
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc = 'mean') # cria a tabela cruzada com um valor específico aplicando uma função desejada
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
fig, axs = plt.subplots(1,2,figsize=(20,8))

ax = sns.scatterplot(x='g0', y='g3', ax=axs[0], data=dados) 
ax = sns.scatterplot(x='g0', y='g8', ax=axs[1], data=dados)

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}) #linear model com tudo misturado

# %%
sns.lmplot(data=dados, x='g0', y='g8', line_kws={'color':'red'}, col='tempo', row='tratamento') #linear model com separado por tratamento e tempo

# %%
corr_gen = dados.loc[:,'g0':'g50'].corr() # calcula correlação entre variáveis. [-1,1] => altamente correlacionadas, ~=0 -> pouco correlacionadas
corr_gen.head()
# Out:
#           g0        g1        g2  ...       g48       g49       g50
# g0  1.000000  0.086032  0.176188  ...  0.238235  0.310583 -0.560201
# g1  0.086032  1.000000 -0.054518  ...  0.029064 -0.106349 -0.028870
# g2  0.176188 -0.054518  1.000000  ...  0.039119  0.052003 -0.140002
# g3  0.011266 -0.027855  0.042633  ...  0.173796  0.072970 -0.233491
# g4  0.403153  0.193647  0.013968  ...  0.006138  0.114748 -0.315675
#
# [5 rows x 51 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_gen, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_gen, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_cel = dados.loc[:,'c0':'c50'].corr() # calcula correlação entre variáveis. [-1,1] => altamente correlacionadas, ~=0 -> pouco correlacionadas
corr_cel.head()
# Out:
#           c0        c1        c2  ...       c48       c49       c50
# c0  1.000000  0.827336  0.848472  ...  0.778280  0.792811  0.797689
# c1  0.827336  1.000000  0.901416  ...  0.853745  0.845159  0.839386
# c2  0.848472  0.901416  1.000000  ...  0.863002  0.853704  0.848724
# c3  0.798830  0.808364  0.830759  ...  0.804207  0.818632  0.821138
# c4  0.840695  0.879258  0.909991  ...  0.862338  0.855029  0.851843
#
# [5 rows x 51 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_cel, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_cel, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Desafio 01: Criar tabelas de frequência com pandas.groupby

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc = 'mean') # cria a tabela cruzada com um valor específico aplicando uma função desejada
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados.groupby(['tratamento','dose','tempo'])['g0'].mean().unstack(level=0)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# ### Desafio 02: Normalizar o crosstab pela coluna

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index') # normaliza o dataframe pelos índices (linhas)
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='columns') # normaliza o dataframe pelos colunas
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ### Desafio 03: Explorar outros agregadores

# %%
dados.groupby(['tratamento','dose','tempo'])['g0'].describe()
# Out:
#                           count      mean       std  ...      50%      75%     max
# tratamento   dose tempo                              ...
# com_controle D1   24      301.0 -0.251760  0.751395  ... -0.29120  0.18600   3.226
#                   48      343.0 -0.122773  0.853396  ... -0.21450  0.38160   3.423
#                   72      307.0 -0.295271  0.769294  ... -0.36550  0.19925   2.584
#              D2   24      305.0  0.010754  0.836626  ...  0.00960  0.56950   2.601
#                   48      305.0  0.013174  0.836845  ... -0.05060  0.42590   4.335
#                   72      305.0  0.070250  0.878041  ...  0.05280  0.58420   4.670
# com_droga    D1   24     3585.0  0.367996  1.461954  ...  0.02700  0.58860   9.908
#                   48     4011.0  0.412469  1.693903  ...  0.01620  0.64860  10.000
#                   72     3600.0  0.286250  1.458600  ...  0.02615  0.54780   9.355
#              D2   24     3581.0  0.115253  1.044999  ... -0.02610  0.49940   7.167
# ...

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc = 'mean') # agregador usado na aula
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc = 'min')
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc = 'max')
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc = 'count')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# ### Desafio 04: Explorar o melt

# %%
dados.melt(id_vars=['tratamento','dose','tempo'], value_vars=['g0','g1']).sample(5)
# Out:
#       tratamento dose  tempo variable   value
# 28186  com_droga   D2     72       g1 -0.9747
# 2017   com_droga   D2     72       g0 -0.5087
# 11203  com_droga   D2     72       g0  0.6869
# 34301  com_droga   D2     72       g1 -1.4630
# 36599  com_droga   D1     48       g1 -1.0920

# %% [markdown]
# ### Desafio 05: Calcular e analisar a correlação entre g's e c's. Refletir sobre os efeitos biológicos

# %%
# correlações entre g's vista em aula

corr_gen = dados.loc[:,'g0':'g50'].corr() # calcula correlação entre variáveis. [-1,1] => altamente correlacionadas, ~=0 -> pouco correlacionadas
corr_gen.head()
# Out:
#           g0        g1        g2  ...       g48       g49       g50
# g0  1.000000  0.086032  0.176188  ...  0.238235  0.310583 -0.560201
# g1  0.086032  1.000000 -0.054518  ...  0.029064 -0.106349 -0.028870
# g2  0.176188 -0.054518  1.000000  ...  0.039119  0.052003 -0.140002
# g3  0.011266 -0.027855  0.042633  ...  0.173796  0.072970 -0.233491
# g4  0.403153  0.193647  0.013968  ...  0.006138  0.114748 -0.315675
#
# [5 rows x 51 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_gen, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_gen, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
gxc = pd.concat([dados.loc[:,'g0':'g50'],dados.loc[:,'c0':'c50']],axis=1).corr() # calcula correlação entre variáveis. [-1,1] => altamente correlacionadas, ~=0 -> pouco correlacionadas
gxc.head()
# Out:
#           g0        g1        g2  ...       c48       c49       c50
# g0  1.000000  0.086032  0.176188  ... -0.595291 -0.609109 -0.594011
# g1  0.086032  1.000000 -0.054518  ... -0.006228  0.027230  0.017267
# g2  0.176188 -0.054518  1.000000  ... -0.160305 -0.167884 -0.153191
# g3  0.011266 -0.027855  0.042633  ... -0.058527 -0.033818 -0.012714
# g4  0.403153  0.193647  0.013968  ... -0.349730 -0.349804 -0.360544
#
# [5 rows x 102 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(gxc, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(gxc, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Desafio 06: Estudar o código que plota a matriz de correlação

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(gxc, dtype=bool)) # cria uma máscara nos dados do dataframe (gxc) selecionando o triângulo superior da matriz partindo da diagonal central (k=0). O parâmetro dtype=bool transforma os valores em booleanos

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9)) # define os objetos gráficos e o tamanho das figuras

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True) # cria um custom colormap para ser usado no heatmap

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(gxc, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}) # plota o gráfico do tipo heatmap utilizando o custom cmap e o mask criados anteriormente. O parâmetro mask usa o triângulo superior para esconder os valores da matriz.

# %% [markdown]
# ### Desafio 07: Resumir do que aprendeu com os dados.

# %% [markdown]
# 1. A figura de correlação entre genes (ou entre células) leva a inferir sobre o impacto da resposta genética de um gene no outro. Entretanto, tais inferências devem ser feitas com muito cuidado, pois correlação não indica causa-consequência. Uma apresentação com melhor potencial seria avaliar aa impacto das ações (tratamento,dose,tempo) na resposta genética de cada gene - avaliações feitas anteriormente.
#
# 2. As tabelas utilizando as técnicas de agregadores e cruzamento dados são ferramentas excelentes para o estudo mais aprofundado dos dados, permitindo quebrar a base de dados grandes, como nesse caso, em tabelas menores e, consequentemente, análises menores.
